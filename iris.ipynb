# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = load_iris(as_frame=True)
df = iris.frame

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
species_mapper = {
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}

df['species'] = df['target'].map(species_mapper)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
cols = df.columns.tolist()
cols
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)',
#  'target',
#  'species']

# %%
col_mapper = {
    'sepal length (cm)':'sepal_length',
    'sepal width (cm)':'sepal_width',
    'petal length (cm)':'petal_length',
    'petal width (cm)':'petal_width',
}

df = df.rename(columns=col_mapper)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target species
# 0           5.1          3.5           1.4          0.2       0  setosa
# 1           4.9          3.0           1.4          0.2       0  setosa
# 2           4.7          3.2           1.3          0.2       0  setosa
# 3           4.6          3.1           1.5          0.2       0  setosa
# 4           5.0          3.6           1.4          0.2       0  setosa

# %%
df['species'].value_counts(normalize=True)
# Out:
# species
# setosa        0.333333
# versicolor    0.333333
# virginica     0.333333
# Name: proportion, dtype: float64

# %%
df.isna().any().any()
# Out:
# False

# %%
df.duplicated().any()
# Out:
# True

# %%
num_var = df.select_dtypes(include='number').columns.drop('target').tolist()
num_var
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
plt.hist(df['sepal_length'], bins=12)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')
plt.title('Distribution of Sepal Length')
plt.show()

# %%
plt.hist(df['sepal_width'], bins=12)
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Count')
plt.title('Distribution of Sepal Width')
plt.show()

# %%
plt.hist(df['petal_length'], bins=12)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count')
plt.title('Distribution of Petal Length')
plt.show()

# %%
plt.hist(df['petal_width'], bins=12)
plt.xlabel('Petal width (cm)')
plt.ylabel('Count')
plt.title('Distribution of Petal Width')
plt.show()

# %%
sns.histplot(data=df, x='sepal_length', hue='species')
plt.xlabel('Petal width (cm)')
plt.ylabel('Count')
plt.title('Distribution of Sepal Length by Species')
plt.show()

# %%
sns.histplot(data=df, x='sepal_width', hue='species')
plt.xlabel('Sepal width (cm)')
plt.ylabel('Count')
plt.title('Distribution of Sepal Width by Species')
plt.show()

# %%
sns.histplot(data=df, x='petal_length', hue='species')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Count')
plt.title('Distribution of Petal Length by Species')
plt.show()

# %%
sns.histplot(data=df, x='petal_width', hue='species')
plt.xlabel('Petal width (cm)')
plt.ylabel('Count')
plt.title('Distribution of Petal Width by Species')
plt.show()

# %%
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species')
plt.title('Petal Length vs. Width')
plt.show()

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
plt.title('Sepal Length vs. Width')
plt.show()

# %%
sns.pairplot(df[num_var])
plt.show()

# %%
sns.boxplot(data=df, x='species', y='sepal_length', hue='species')
plt.show()

# %%
sns.boxplot(data=df, x='species', y='sepal_width', hue='species')
plt.show()

# %%
sns.boxplot(data=df, x='species', y='petal_length', hue='species')
plt.show()

# %%
sns.boxplot(data=df, x='species', y='petal_width', hue='species')
plt.show()

# %%
sns.countplot(data=df, x='species')
plt.show()

# %%
# Creating summary table of mean and standard deviation for sepal length

sl_summary = df.groupby('species')['sepal_length'].agg(['mean','std'])
sl_summary
# Out:
#              mean       std
# species
# setosa      5.006  0.352490
# versicolor  5.936  0.516171
# virginica   6.588  0.635880

# %%
# Creating column for coefficient of variation

sl_summary['cv'] = sl_summary['std'] / sl_summary['mean']
sl_summary['cv']
# Out:
# species
# setosa        0.070413
# versicolor    0.086956
# virginica     0.096521
# Name: cv, dtype: float64

# %%
# Graphing the mean sepal length with error bars of +/- 1 std

plt.errorbar(x=sl_summary['mean'].index, y=sl_summary['mean'], yerr=sl_summary['std'], fmt='o', capsize=5)
plt.show()

# %%
# Summary table for sepal width

sw_summary = df.groupby('species')['sepal_width'].agg(['mean','std'])
sw_summary['cv'] = sw_summary['std'] / sw_summary['mean']
sw_summary
# Out:
#              mean       std        cv
# species
# setosa      3.428  0.379064  0.110579
# versicolor  2.770  0.313798  0.113285
# virginica   2.974  0.322497  0.108439

# %%
# Graphing mean with error bars

plt.errorbar(x=sw_summary['mean'].index, y=sw_summary['mean'], yerr=sw_summary['std'], fmt='o', capsize=5)
plt.show()

# %%
pl_summary = df.groupby('species')['petal_length'].agg(['mean','std'])
pl_summary['cv'] = pl_summary['std'] / pl_summary['mean']

pl_summary
# Out:
#              mean       std        cv
# species
# setosa      1.462  0.173664  0.118785
# versicolor  4.260  0.469911  0.110308
# virginica   5.552  0.551895  0.099405

# %%
# Graphing mean petal length with error bars

plt.errorbar(x=pl_summary['mean'].index, y=pl_summary['mean'], yerr=pl_summary['std'], fmt='o', capsize=5)
plt.show()

# %%
pw_summary = df.groupby('species')['petal_width'].agg(['mean','std'])
pw_summary['cv'] = pw_summary['std'] / pw_summary['mean']

pw_summary
# Out:
#              mean       std        cv
# species
# setosa      0.246  0.105386  0.428397
# versicolor  1.326  0.197753  0.149135
# virginica   2.026  0.274650  0.135563

# %%
# Graphing petal width mean with error bars

plt.errorbar(x=pw_summary['mean'].index, y=pw_summary['mean'], yerr=pw_summary['std'], fmt='o', capsize=5)
plt.show()

# %%
df.groupby('species').describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.428000    2.770000   2.974000
#              std     0.379064    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.200000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
#              mean    1.462000    4.260000   5.552000
#              std     0.173664    0.469911   0.551895
#              min     1.000000    3.000000   4.500000
#              25%     1.400000    4.000000   5.100000
#              50%     1.500000    4.350000   5.550000
#              75%     1.575000    4.600000   5.875000
#              max     1.900000    5.100000   6.900000
# petal_width  count  50.000000   50.000000  50.000000
#              mean    0.246000    1.326000   2.026000
#              std     0.105386    0.197753   0.274650
#              min     0.100000    1.000000   1.400000
#              25%     0.200000    1.200000   1.800000
#              50%     0.200000    1.300000   2.000000
#              75%     0.300000    1.500000   2.300000
#              max     0.600000    1.800000   2.500000
# target       count  50.000000   50.000000  50.000000
#              mean    0.000000    1.000000   2.000000
#              std     0.000000    0.000000   0.000000
#              min     0.000000    1.000000   2.000000
#              25%     0.000000    1.000000   2.000000
#              50%     0.000000    1.000000   2.000000
#              75%     0.000000    1.000000   2.000000
#              max     0.000000    1.000000   2.000000

# %%
df.groupby('species').var(ddof=0)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  target
# species
# setosa          0.121764     0.140816      0.029556     0.010884     0.0
# versicolor      0.261104     0.096500      0.216400     0.038324     0.0
# virginica       0.396256     0.101924      0.298496     0.073924     0.0
